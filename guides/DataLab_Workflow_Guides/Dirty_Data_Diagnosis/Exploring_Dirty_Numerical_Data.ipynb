# %% [markdown]
# # **Dirty Data Diagnosis Workflow Guide - Numerical**

# %% [markdown]
# ### Welcome to the Workflow Guide for Diagnosing Dirty Numerical Data!
#
# In this workflow guide, we will explore how we can diagnose dirty numerical data using datalabx.

# %% [markdown]
# ### **Importing Libraries**
#
# To begin with, we will be importing:
#
# - datalabx

# %%
import datalabx

# %% [markdown]
# ### **Loading the Data**
#
# In this Guide, we will be using an extremely dirty synthetic however, realistic numerical dataset.

# %%
from datalabx import load_tabular

df = load_tabular('ultra_messy_dataset.csv')
df.head()
# Out:
#                   Age                  Salary               Expenses  \
# 0                five                1.04e+05      4735.244618878169
# 1  20.673408544550288      134460.66741276794    9533.158420128186
# 2               33.56                 missing               4104.95
# 3             missing                    None                 894429
# 4                 28$    112877.67251785153                  1040.45
#
#    Height_cm          Weight_kg Temperature_C     Purchase_Amount  Score  \
# 0   1,55e+02               None       unknown                None  30.70
# 1   1,53e+02              12193      2.05e+01            2.40e+03    one
# 2        204  96.50051410846052     -1,14e+01  2877.0871437672777   four
# 3  196.34 cm                  ?     -1.57e+01                None      ?
# 4  171.40 cm              49,12            -6            4344.39    2.24
#
#               Rating                  Debt
# 0  4.888018131992931                64,972
# 1           3,33e+00            $58,276.81
# 2            unknown    94033.3425007563
# 3               4.31              27,400cm
# 4               4.14                 67682

# %% [markdown]
# ### **Checking Datatypes**
#
# This step is quite important because:
#
# - Beginning with **v0.1.0b4**, datalabx loads a pandas DataFrame with all columns with **string** datatype.
# - This step ensures that Dirty Data detection can be easier and consistent to work with.

# %%
df.dtypes
# Out:
# Age                object
# Salary             object
# Expenses           object
# Height_cm          object
# Weight_kg          object
# Temperature_C      object
# Purchase_Amount    object
# Score              object
# Rating             object
# Debt               object
# dtype: object

# %% [markdown]
# Great!
#
# We can see that all columns are of string datatype.

# %% [markdown]
# ### **Diagnosing Dirty Data**
#
# Using datalabx, we can explore several kinds of inconsistencies and formatting issues that may be visible or invisible in a dataset.
#
# In order to explore issues or dirt in our data, we can import ``DirtyDataDiagnosis`` class.

# %%
from datalabx import DirtyDataDiagnosis

# %% [markdown]
# #### **Diagnosing Dirty Numerical Data**
#
# Since datalabx allows us to diagnose numerical data separately, we can diagnose issues in a dirty numerical dataset using ``diagnose_numbers()`` method from the **DirtyDataDiagnosis** class.
#
# We can also see what all diagnostic methods we have available in ``diagnose_numbers()`` method, by passing **show_available_methods=True**.

# %%
diagnosis = DirtyDataDiagnosis(df).diagnose_numbers(show_available_methods=True)
# Out:
# DirtyDataDiagnosis - INFO - Dirty Data Diagnosis initialized with auto backend.
# DirtyDataDiagnosis - INFO - Available diagnostic methods: ['is_valid', 'is_dirty', 'is_text', 'is_symbol', 'is_missing', 'is_scientific_notation', 'has_units', 'has_symbols', 'has_commas', 'has_currency', 'has_multiple_decimals', 'has_multiple_commas', 'has_spaces', 'has_decimals', 'has_text']

# %% [markdown]
# As we can see that after using **show_available_methods=True**, we can see a whole list of diagnostics, which is helpful for reference.

# %% [markdown]
# #### **Exploring Dirty Numerical Data**
#
# All Dirty Data Diagnosis methods follow the following pattern for ease of access:
#
# ``diagnosis[column_name][diagnostic_method]``
#
# Let us look at an example of that:

# %%
diagnosis['Age']['is_dirty'].head(5)
# Out:
#             Age                  Salary           Expenses  Height_cm  \
# index
# 0          five                1.04e+05  4735.244618878169   1,55e+02
# 3       missing                    None             894429  196.34 cm
# 4           28$    112877.67251785153              1040.45  171.40 cm
# 5           N/A                97,011cm  3940.648823758793        193
# 6      1,62e+00                    None                  ?     188.38
#
#       Weight_kg Temperature_C Purchase_Amount     Score              Rating  \
# index
# 0          None       unknown            None     30.70   4.888018131992931
# 3             ?     -1.57e+01            None         ?                4.31
# 4         49,12            -6        4344.39       2.24                4.14
# 5         72.02   approx 1000        4.68e+03         ?  1.4870053742777882
# 6           13W        -17.10         4939.82  1,37e+01         approx 1000
#
#             Debt
# index
# 0         64,972
# 3       27,400cm
# 4          67682
# 5           None
# 6      49,979,88

# %% [markdown]
# As we can see in the above example that we get a DataFrame of rows where values are dirty in the selected column, and also corresponding values in other columns.
#
# We will now explore all the available diagnostic methods to see how datalabx helps in detecting dirty data.

# %% [markdown]
# ##### 1. **is_valid** -> Numbers containing only valid integers or decimals

# %%
diagnosis['Salary']['is_valid']
# Out:
#                          Age              Salary               Expenses  \
# index
# 1         20.673408544550288  134460.66741276794    9533.158420128186
# 8         19.668785230642992              113743                   None
# 16               approx 1000            14323039                6692,39
# 17         80.26378710785808               37520                   6196
# 20       31.76114435883044     84341.40047685153                 375313
# ...                      ...                 ...                    ...
# 99975                      ?   60113.35587059199                 5,927#
# 99985               5.31e+01              41.000                      ?
# 99986                     86   91419.30329171919              $1,552.59
# 99996               4.67e+01               44685               8926.38
# 99997                    one               59323                      ?
#
#                     Height_cm           Weight_kg          Temperature_C  \
# index
# 1                    1,53e+02               12193               2.05e+01
# 8                       209cm            7,41e+01                   -047
# 16       200.21752547959585                   N/A    -5.95023300841531
# 17                     170,96                  8e                  error
# 20                  157.54 cm  45.687369632176015                   None
# ...                       ...                 ...                    ...
# 99975                       ?                None               2.60e+01
# 99985                    None                 N/A                   five
# 99986                     one             unknown                 -14,40
# 99996               169.24 cm                   ?                  -1.87
# 99997               149.06 cm                  62                      ?
#
#       Purchase_Amount        Score                  Rating        Debt
# index
# 1            2.40e+03          one                3,33e+00  $58,276.81
# 8                None  approx 1000                    1.76     7009614
# 16            2805.74           53                3.55e+00      60.441
# 17             108278        77,15    2.0633347862257705       37,569$
# 20                two      unknown                    1,93         one
# ...               ...          ...                     ...         ...
# 99975            4837        28,22      1.7935389974553844    2,18e+04
# 99985           40847       24.45                     None           ?
# 99986     USD4,000.28       60.42                      415      6,054$
# 99996        3.57e+03     1,53e+01                    3.06         one
# 99997            None           9#                     3kg        five
#
# [27455 rows x 10 columns]

# %% [markdown]
# We can see:
#
# - Rows containing valid data in selected column **'Salary'** along with corresponding values in other columns.
#
# - That in the selected column **'Salary'** at **row 99985**, we have **41.000**.
#
# This means converting data like this directly into numbers may not be a right choice, and requires careful cleaning.
#
# However, in this guide we are only exploring how we can diagnose such hostile data with datalabx.

# %% [markdown]
# ##### 2. **is_dirty** -> Values that are not strictly numeric

# %%
diagnosis['Salary']['is_dirty']
# Out:
#                      Age                  Salary           Expenses  \
# index
# 0                   five                1.04e+05  4735.244618878169
# 2                  33.56                 missing           4104.95
# 4                    28$    112877.67251785153              1040.45
# 5                    N/A                97,011cm  3940.648823758793
# 7                   4748               122355,46               None
# ...                  ...                     ...                ...
# 99992               17cm               79100.25   7126.922194644891
# 99993            unknown                     one              519kg
# 99995  58.46412848279316               171670,06           4.74e+03
# 99998  73.77945243627492               134,820cm               None
# 99999  96.85051867823643               191,00309               None
#
#                     Height_cm          Weight_kg      Temperature_C  \
# index
# 0                    1,55e+02               None            unknown
# 2                         204  96.50051410846052          -1,14e+01
# 4                   171.40 cm              49,12                 -6
# 5                         193              72.02        approx 1000
# 7        206.76284108092278              unknown               3061
# ...                       ...                ...                ...
# 99992                1,63e+02                 56               five
# 99993                  168.45           1.24e+02            13.27 C
# 99995                   error                  ?             -18,03
# 99998                    None                124  49.24252868950967
# 99999                       ?             128.92               None
#
#            Purchase_Amount              Score              Rating  \
# index
# 0                     None              30.70   4.888018131992931
# 2       2877.0871437672777               four             unknown
# 4                 4344.39                2.24                4.14
# 5                 4.68e+03                  ?  1.4870053742777882
# 7      -3813.6973731160588                10$                None
# ...                    ...                ...                 ...
# 99992          approx 1000               None  3.7461261651622686
# 99993                 2676                  ?                None
# 99995                 3K60                 40               1.18
# 99998                   53  92.33288196735303                2.57
# 99999                 None               0,13                3.57
#
#                         Debt
# index
# 0                     64,972
# 2         94033.3425007563
# 4                      67682
# 5                       None
# 7                       None
# ...                      ...
# 99992               6,42e+04
# 99993                  48997
# 99995              47,993,91
# 99998    56363.25637056529
# 99999             £55,496.10
#
# [60042 rows x 10 columns]

# %% [markdown]
# We can see:
#
# - Rows containing dirty data in selected column **'Salary'** along with corresponding values in other columns.
#
# - At **rows 4 and 99992**, we have values that look like valid numbers, so why are they detected as dirty?
#
# Well, we will exploring that next.

# %% [markdown]
# ##### 3. **has_spaces** -> Numbers with leading or trailing spaces

# %%
diagnosis['Salary']['has_spaces']
# Out:
#                       Age                  Salary                Expenses  \
# index
# 4                     28$    112877.67251785153                   1040.45
# 12      56.54658961646852              117093.88                      280
# 24     14.804404681617523              163626.39                     None
# 26                   None              177863.96      6907.200431442799
# 29                   None    150576.34139633976         9701.922363121375
# ...                   ...                     ...                     ...
# 99968                 077              159898.19                     None
# 99976                 N/A              149996.29                     four
# 99983               17.36     72039.32150316115      3166.4743189371625
# 99989                 one      85135.0577649094                 £8,970.84
# 99992                17cm               79100.25        7126.922194644891
#
#                     Height_cm Weight_kg Temperature_C         Purchase_Amount  \
# index
# 4                   171.40 cm     49,12            -6                4344.39
# 12                  209.39 cm     10830          4710                      39
# 24                        one      None          0.15    2594.3002316877773
# 26         192.04280102035187      None       unknown                    None
# 29       181.51512589672436       13380        -13,78                    1489
# ...                       ...       ...           ...                     ...
# 99968                   19630     three         49.36                1.01e+03
# 99976                     149    134,83            42                  2,278$
# 99983      159.47231001453957        62            26                  4,846#
# 99989      154.68503873178864      four           N/A                   86498
# 99992                1,63e+02        56          five             approx 1000
#
#                     Score              Rating       Debt
# index
# 4                    2.24                4.14      67682
# 12                      ?                None    missing
# 24                      2                   3      47772
# 26                   None                  1$   23,704cm
# 29     3.5289259277817897                3.85   74363.81
# ...                   ...                 ...        ...
# 99968               error                None    missing
# 99976               54.77                   ?   34451,33
# 99983                None               2.60       54826
# 99989    84.9798232754922                None  60,578,19
# 99992                None  3.7461261651622686   6,42e+04
#
# [12461 rows x 10 columns]

# %% [markdown]
# We can see:
#
# - That **rows 4 and 99992** were detected as **dirty** because they had spaces, even though they were valid numbers.
#
# Let us verify that by checking representation of data in column **Salary**.

# %%
spaces_in_salary_column = diagnosis['Salary']['has_spaces']

spaces_in_salary_column['Salary'].apply(repr)
# Out:
# index
# 4        '  112877.67251785153  '
# 12                   '117093.88 '
# 24                   '163626.39 '
# 26                   '177863.96 '
# 29       '  150576.34139633976  '
#                    ...
# 99968                '159898.19 '
# 99976                '149996.29 '
# 99983     '  72039.32150316115  '
# 99989      '  85135.0577649094  '
# 99992                 '79100.25 '
# Name: Salary, Length: 12461, dtype: object

# %% [markdown]
# We can verify:
#
# - That we have leading and trailing spaces in our data.
# - Valid numbers containing dirt were correctly identified as **'dirty'**, to prevent errors and failures.

# %% [markdown]
# ##### 4. **is_text** -> Values containing only alphabetic characters and spaces

# %%
diagnosis['Salary']['is_text']
# Out:
#                Age   Salary           Expenses           Height_cm  \
# index
# 2            33.56  missing           4104.95                  204
# 13               ?  unknown        USD1,968.25                 140
# 19              24    error            missing  154.39347845753835
# 21           10.63  missing             4,858$                 158
# 41        3,47e+01      one  7849.991870917486                   ?
# ...            ...      ...                ...                 ...
# 99945           65    error  7733.017450079798                 183
# 99949         8.70     five               12m6         approx 1000
# 99963  approx 1000     five              4.651   179.4574667294149
# 99977           30     four  8510.975305875856                None
# 99993      unknown      one              519kg              168.45
#
#                     Weight_kg            Temperature_C  \
# index
# 2           96.50051410846052                -1,14e+01
# 13                   84.77 kg    -13.963460658813508
# 19                        1d1    -11.799573772015473
# 21                  131.57 kg                     None
# 41                        146                -1,23e+01
# ...                       ...                      ...
# 99945                    None                  43.98 C
# 99949                4.94e+01                        3
# 99963    114.48668243994786                      44,45
# 99977                      G6                     None
# 99993                1.24e+02                  13.27 C
#
#               Purchase_Amount               Score              Rating  \
# index
# 2          2877.0871437672777                four             unknown
# 13                       2615    70.0010216186228                2,01
# 19                       four            8,65e+01               2.72
# 21                    3227,79  2.7084178606550324         approx 1000
# 41                       2470                five                4.74
# ...                       ...                 ...                 ...
# 99945    3296.8437727603455              4,68e+01  3.4208849180608993
# 99949       3879.643378469343   81.50471115201124                None
# 99963                 4,129cm               69.50                   3
# 99977                 3123,00            4.84e+01                4.61
# 99993                    2676                   ?                None
#
#                        Debt
# index
# 2        94033.3425007563
# 13                    528H1
# 19        99873.53508502501
# 21                 68895,51
# 41                        ?
# ...                     ...
# 99945              4,50e+03
# 99949     92682.22547475726
# 99963            £81,550.43
# 99977               20,083#
# 99993                 48997
#
# [9968 rows x 10 columns]

# %% [markdown]
# We can see:
#
# - Rows of data containing only the text values present in selected column.
# - Presence of **numbers in the form of text**. E.g: ``['one', 'four', 'five']``
# - Presence of **missing data placeholders**. E.g: ``['missing', 'unknown', 'error']``

# %% [markdown]
# ##### 5. **is_symbol** -> Values that are only symbols **(anything not text or number).**

# %%
diagnosis['Expenses']['is_symbol']
# Out:
#                Age       Salary Expenses           Height_cm Weight_kg  \
# index
# 6         1,62e+00         None        ?              188.38       13W
# 22              51     9.19e+04        ?               19414  82.92 kg
# 25        8.90e+01       158192        ?                 151      four
# 85     approx 1000     67,169cm        ?  199.07271353242862    122,66
# 87        5,34e+01     30770,53        ?                None      None
# ...            ...          ...      ...                 ...       ...
# 99942         None       119212        ?               error      48kg
# 99952         four  approx 1000        ?  185.46537031537326      None
# 99978       12.29             ?        ?            1.59e+02    129,47
# 99985     5.31e+01       41.000        ?                None       N/A
# 99997          one        59323        ?           149.06 cm        62
#
#              Temperature_C     Purchase_Amount                   Score  \
# index
# 6                   -17.10             4939.82                1,37e+01
# 22      1.6457943767645133             $395.47    48.849217370187525
# 25                    four           £2,337.09                    None
# 85                   30.77                5528                   40.49
# 87                 42.95 C  382.21031260890965                   96.74
# ...                    ...                 ...                     ...
# 99942                 None   4572.038038420724                    None
# 99952  -14.319478982819899            4,25e+03                    five
# 99978                 None  1741.6447996989257      15.464122066700325
# 99985                 five               40847                  24.45
# 99997                    ?                None                      9#
#
#                     Rating                Debt
# index
# 6              approx 1000           49,979,88
# 22                    2,77  61514.218112467155
# 25     -3.3620502805540093               69092
# 85                    None   6838.111785109047
# 87                       G                None
# ...                    ...                 ...
# 99942                    4            48346,42
# 99952                 4.66               51951
# 99978                    2            17684,31
# 99985                 None                   ?
# 99997                  3kg                five
#
# [6229 rows x 10 columns]

# %% [markdown]
# We can see:
#
# - Rows of data containing only symbols present in selected column.
# - Presence of symbols like **'?'**.

# %% [markdown]
# ##### 6. **is_scientific_notation** -> 	Numbers expressed in scientific notation

# %%
diagnosis['Salary']['is_scientific_notation']
# Out:
#             Age    Salary               Expenses          Height_cm  \
# index
# 0          five  1.04e+05      4735.244618878169           1,55e+02
# 22           51  9.19e+04                      ?              19414
# 48            ?  6.34e+04    -3969.8980404480108             197.30
# 83        53.81  1,55e+05                   None                144
# 91         None  4,24e+04     6223.7532314998525             184.82
# ...         ...       ...                    ...                ...
# 99916  1.76e+01  1,83e+05                      ?               None
# 99934     30.53  1,00e+05                   None                one
# 99937      None  3.50e+04    4921.773488771688                    ?
# 99981         5  1,89e+05     183.95536021312876           1,56e+02
# 99984     81.06  1.45e+05                   34c6  157.4644169153445
#
#          Weight_kg       Temperature_C         Purchase_Amount  \
# index
# 0             None             unknown                    None
# 22        82.92 kg  1.6457943767645133                 $395.47
# 48            147$  14.587490438423828    363.54132112663615
# 83             63$            1.07e+00                    3X98
# 91               ?               three                1.72e+03
# ...            ...                 ...                     ...
# 99916  approx 1000                  33                   2,206
# 99934          x26   -5.20507318092902                    None
# 99937         None                  43                 £393.92
# 99981      missing                 N/A       673.6215011527486
# 99984        58.96                  -1       4616.596347279579
#
#                         Score                  Rating                Debt
# index
# 0                       30.70       4.888018131992931              64,972
# 22       48.849217370187525                      2,77  61514.218112467155
# 48                     90.95                      480   34511.48105698926
# 83                      2.62       1.5582989345477651          £18,067.59
# 91                      77.33      3.0364374933598874             1698990
# ...                       ...                     ...                 ...
# 99916                    77cm    2.9472687090768925            £66,390.88
# 99934                      65                     one   77913.45969225027
# 99937                 missing                     1kg          €29,603.02
# 99981                     25#                    None           €1,760.30
# 99984                    None                     two                   ?
#
# [6323 rows x 10 columns]

# %% [markdown]
# We can see:
#
# - Rows containing values that are expressed in scientific notation, in the selected column.
# - Scientific notation values that have decimal points. E.g: ``1.04e+05``
# - Scientific notation values that have commas. E.g: ``1,55e+05``
#
# **NOTE**:
#
# > Even though scientific notations are not dirty numerical data, they just are not the usual way of seeing numbers.

# %% [markdown]
# ##### 7. **is_missing** -> 	Values that are pandas built-in missing values **(NaN, None or NaT)**

# %%
diagnosis['Salary']['is_missing']
# Out:
#                       Age Salary                Expenses           Height_cm  \
# index
# 3                 missing   None                  894429           196.34 cm
# 6                1,62e+00   None                       ?              188.38
# 23                 53.17    None                2375.26                    ?
# 38     63.845197905025486   None                3.39e+03                 two
# 40                   4170   None      -9163.295252169082  158.49341835731576
# ...                   ...    ...                     ...                 ...
# 99967                1331   None     6135.652593031973    149.35239389417842
# 99972   78.65500787712726   None                    65g2                 185
# 99979               17,92   None    4002.7337333716923                  178#
# 99982                   ?   None       4574.147201956746                   ?
# 99994              65.45    None                4.445.34            1.58e+02
#
#                    Weight_kg            Temperature_C        Purchase_Amount  \
# index
# 3                          ?                -1.57e+01                   None
# 6                        13W                   -17.10                4939.82
# 23                      4529                    -3.60                  three
# 38                     137cm                       33                  three
# 40         49.97026332576549     -5.339405691908919      341.7384991212715
# ...                      ...                      ...                    ...
# 99967               4,83e+01                     None     1726.3862998257182
# 99972    70.26295135296155      -2.6470571433522068                     None
# 99979               1,02e+02                  -7.49 C            approx 1000
# 99982                   None       -6.743289763755037    513.3439717515614
# 99994                 116.96                  22.60 C                 2,622$
#
#           Score                  Rating                   Debt
# index
# 3             ?                    4.31               27,400cm
# 6      1,37e+01             approx 1000              49,979,88
# 23         None     -1.5500259276486759    546.9687378848231
# 38            ?     1.549877485863596                 4.20e+02
# 40           6m    1.4979516300582563                     None
# ...         ...                     ...                    ...
# 99967         ?                       ?                  X7977
# 99972        94       1.195301407321253                unknown
# 99979        59      3.9279059376617296                      ?
# 99982     13.55                    3,35               5,39e+04
# 99994   unknown                       ?                  error
#
# [12503 rows x 10 columns]

# %% [markdown]
# We can see:
#
# - Rows containing pandas built-in missing values in the selected column.
# - Presence of **None**.

# %% [markdown]
# ##### 8. **has_commas** -> Numbers that contain single commas.

# %%
diagnosis['Salary']['has_commas']
# Out:
#                           Age     Salary               Expenses  \
# index
# 7                        4748  122355,46                   None
# 14                         89  191,15589      6110.901653052778
# 44                         37  193018,84               7,32e+03
# 47                          ?  173,54524                    one
# 54          7.406576281928611   99194,11                unknown
# ...                       ...        ...                    ...
# 99950                    None     91,256    7315.909551677584
# 99980    49.992466371566216    105570,82               6.73e+03
# 99991      -73.86346439365516  170514,39                   None
# 99995       58.46412848279316  171670,06               4.74e+03
# 99999       96.85051867823643  191,00309                   None
#
#                     Height_cm Weight_kg          Temperature_C  \
# index
# 7        206.76284108092278     unknown                   3061
# 14                     203,45     13296                     49
# 44                        146      111#    -29.004856251571162
# 47                     206.86        cc                  -1707
# 54       169.55197193077123       61.02    18.48512229150878
# ...                       ...       ...                    ...
# 99950                  186.40         ?                     23
# 99980                     two      5243                  47.46
# 99991                   157kg      None    16.48352001523763
# 99995                   error         ?                 -18,03
# 99999                       ?    128.92                   None
#
#            Purchase_Amount               Score              Rating  \
# index
# 7      -3813.6973731160588                 10$                None
# 14                1602.82    89.72625151867503                   1
# 44                       ?               56.17                None
# 47                2,86e+03                   ?               4.44
# 54                    None                None                   4
# ...                    ...                 ...                 ...
# 99950                 4455                99kg                   4
# 99980                 four                  2$  2.7478660020037577
# 99991                 1144  -52.52890051132507               3.05
# 99995                 3K60                  40               1.18
# 99999                 None                0,13                3.57
#
#                      Debt
# index
# 7                    None
# 14                   None
# 44                  83693
# 47                2630479
# 54                      ?
# ...                   ...
# 99950  -24727.72113548849
# 99980                None
# 99991            17719,74
# 99995           47,993,91
# 99999          £55,496.10
#
# [5283 rows x 10 columns]

# %% [markdown]
# We can see:
#
# - Rows containing numbers with commas in the selected column.
# - Commas being used as thousand separator. E.g: ``91,256``
# - Commas being used as decimal replacement. E.g: `99194,11`

# %% [markdown]
# ##### 9. **has_units** -> Numbers suffixed with alphabetical units

# %%
diagnosis['Salary']['has_units']
# Out:
#                         Age     Salary              Expenses  \
# index
# 5                       N/A   97,011cm     3940.648823758793
# 9                         ?  114,154kg    3886.04358926301
# 11                     5405   84,570kg                  3565
# 18                     7794  167,059kg    3305.7506022186312
# 85              approx 1000   67,169cm                     ?
# ...                     ...        ...                   ...
# 99890                 86,52     11878g                 7,194
# 99926                  None  174,203kg                  5565
# 99943    74.4200605300671     42,646kg     494.5423936608717
# 99988                 error   54,060cm               unknown
# 99998     73.77945243627492  134,820cm                  None
#
#                     Height_cm           Weight_kg      Temperature_C  \
# index
# 5                         193               72.02        approx 1000
# 9                        None                67cm           4.19e+01
# 11                     191,78                  90              three
# 18        140.0933932430345                    59            unknown
# 85         199.07271353242862              122,66              30.77
# ...                       ...                 ...                ...
# 99890    204.99880867126944    123.98636363182037               None
# 99926                    None                None               None
# 99943                    None                None                -Q8
# 99988       195.1132301157852               55,80            -1.45 C
# 99998                    None                 124  49.24252868950967
#
#           Purchase_Amount               Score                  Rating  \
# index
# 5                4.68e+03                   ?      1.4870053742777882
# 9                    None                   ?                    four
# 11               4.01e+03  -46.50775056319312                    None
# 18                      ?               17.66                       2
# 85                   5528               40.49                    None
# ...                   ...                 ...                     ...
# 99890            2,744,55  -55.50372598636834                     279
# 99926             4045,29   87.87463218920847      3.7374133373046017
# 99943    820.115047444307                None                       g
# 99988  269.98156504071824   82.24745040715497    4.0062028980917335
# 99998                  53   92.33288196735303                    2.57
#
#                         Debt
# index
# 5                       None
# 9                       None
# 11                   7675,58
# 18                 €1,365.37
# 85         6838.111785109047
# ...                      ...
# 99890             €85,266.94
# 99926                8858810
# 99943                   7875
# 99988                  89986
# 99998    56363.25637056529
#
# [3518 rows x 10 columns]

# %% [markdown]
# We can see:
#
# - Rows of numbers containing units like `'cm'`, `'kg'` or `'C'`.
#
# - Presence of units in **Salary** column, which should not be the case.

# %% [markdown]
# ##### 10. **has_symbols** -> Numbers containing non-alphanumeric or special symbols

# %%
diagnosis['Expenses']['has_symbols']
# Out:
#                           Age              Salary Expenses          Height_cm  \
# index
# 72                    unknown              157130   1,584#                201
# 133                      five                None   7,489#  191.1978074857144
# 288                      None  174587.84885026535     613#           1.95e+02
# 327      25.430754502321705             176320.83   5,064#        approx 1000
# 379                     three          $21,861.45   5,136#               None
# ...                       ...                 ...      ...                ...
# 99787                  94.42                6696u   2,437#              184kg
# 99796    53.591163687381105              2.70e+04   8,440#             184.89
# 99871                       ?            32672.15   2,385#                  ?
# 99883                 missing            47814.02   2,442#             189.36
# 99975                       ?   60113.35587059199   5,927#                  ?
#
#                Weight_kg            Temperature_C        Purchase_Amount  \
# index
# 72                     ?                     3.39                   None
# 133                error                     2822                   None
# 288    40.66640021440021     -3.686203201619353       3469.1026930108605
# 327                42.96    -17.696365801547106                 3,314,80
# 379            123.14 kg                     None                   None
# ...                  ...                      ...                    ...
# 99787               None     48.176052012252626                  1,301cm
# 99796             109.10                        8    3860.263958816173
# 99871                 81                    36.77                   None
# 99883              72.19                       29                      ?
# 99975               None                 2.60e+01                   4837
#
#                    Score              Rating        Debt
# index
# 72                   two                 3kg    8,50e+04
# 133                 None                2,71           ?
# 288    50.66165359258081         approx 1000       4412Y
# 327                   65                   1  $47,926.99
# 379                 None                five  £16,680.45
# ...                  ...                 ...         ...
# 99787              54,71                1.05        None
# 99796             96.60             1,76e+00    6.43e+03
# 99871                  5                   4        None
# 99883              three                   4    13874.71
# 99975              28,22  1.7935389974553844    2,18e+04
#
# [1611 rows x 10 columns]

# %% [markdown]
# We can see:
#
# - Rows containing numbers with symbols in the selected column.
#
# - Presence of symbols like ``','`` and ``#`` at the middle or end of numbers.

# %% [markdown]
# ##### 11. **has_currency** -> Numbers containing currency symbols **(start or end)**

# %%
diagnosis['Salary']['has_currency']
# Out:
#                           Age       Salary            Expenses  \
# index
# 10                        N/A  £174,199.87   4391.802671782378
# 31       30.509111667917633     £56,122.72              775483
# 68                          ?  €187,848.32                993$
# 76                          3   €70,388.25            8.45e+03
# 103         97.72722836210654  £183,864.54            9354.24
# ...                       ...          ...                 ...
# 99893                   59.45     101,638$            3952.90
# 99927                       ?  £148,827.03            3,92e+03
# 99935                  90.47   €103,742.85                 one
# 99960                5.00e+01   €75,166.97             unknown
# 99969                 unknown      94,635$  3497.2552537776533
#
#                     Height_cm              Weight_kg          Temperature_C  \
# index
# 10         185.76848542242396                  14987      33.94610237955915
# 31                        172              104.15 kg                  48,15
# 68                       five     60.907042770125216                  46.41
# 76                       None    115.9444747337286                     -16$
# 103        186.01437317034862                     9h                  35.30
# ...                       ...                    ...                    ...
# 99893                   error                    86#    14.82357384827251
# 99927                  141.04                  73.53                   None
# 99935                   154kg                   five                  -14kg
# 99960                    None                   55kg              -3,97e+00
# 99969    163.21508945459948                     four       36.1663842985723
#
#          Purchase_Amount               Score              Rating  \
# index
# 10              3.43e+03                five                2.46
# 31                  None            4.79e+01   4.940423406622413
# 68                     ?                 81$  1.1427688707982004
# 76              4,91e+03                3751            2.27e+00
# 103    -3295.56172482079  19.444189640075727  1.2066048806475855
# ...                  ...                 ...                 ...
# 99893               None                None                 359
# 99927                  ?                 two  1.3382789658845238
# 99935              4.774                  59                None
# 99960                one                   ?                3.20
# 99969               C518               34.47  2.9459997397736677
#
#                         Debt
# index
# 10                  75,920cm
# 31       43176.67103678792
# 68                      None
# 76                      None
# 103        61839.53758801937
# ...                      ...
# 99893     13961.242334451885
# 99927               69,13119
# 99935               3.53e+04
# 99960                   None
# 99969                unknown
#
# [6180 rows x 10 columns]

# %% [markdown]
# We can see:
#
# - Rows containing numbers with currency symbols in the selected column.
# - Presence of currency symbols at beginning. E.g: **[£174,199.87, €187,848.32]**
# - Presence of currency symbols at end. E.g: **(94,635$)**

# %% [markdown]
# ##### 12. **has_text** -> Numbers containing text

# %%
diagnosis['Salary']['has_text']
# Out:
#                          Age         Salary               Expenses  \
# index
# 59        13.515496581453446  USD111,650.31                   None
# 80                   unknown    approx 1000    6113.738800120347
# 116                    error         15O656               5.49e+03
# 128      64.92559276385012      approx 1000                 1,660$
# 157                   37.30     approx 1000               2.83e+03
# ...                      ...            ...                    ...
# 99876                  three          XX940                   67P8
# 99917    44.99271101319163      approx 1000                3801,65
# 99952                   four    approx 1000                      ?
# 99973                  25.70         A43A05      9869.054693635251
# 99987      84.67530381078537         116c48                7,748cm
#
#                    Height_cm               Weight_kg        Temperature_C  \
# index
# 59                      None                   98.97                 -2kg
# 80                     14401                      47                  11$
# 116                    16964                    5471              missing
# 128                  missing                77.23 kg              13.44 C
# 157       143.09249712048197                    None                  two
# ...                      ...                     ...                  ...
# 99876                 190,44    51.485878574281934                  -7,07
# 99917    140.4200740287813                       135                 None
# 99952     185.46537031537326                    None  -14.319478982819899
# 99973              190.25 cm                    None                error
# 99987                    158                   76.44                 45cm
#
#               Purchase_Amount                Score                  Rating  \
# index
# 59       2439.8053177914226                     7G                     284
# 80                USD1,137.55          approx 1000                    four
# 116         657.0642569987274  -60.629991444131136                    None
# 128                     error                 None                   three
# 157                  3,32e+03                 None                       ?
# ...                       ...                  ...                     ...
# 99876    3557.5681292097497     11.040612809705896                 missing
# 99917                 154.09                     ?    2.3625033484864897
# 99952                4,25e+03                 five                    4.66
# 99973                    4354                 1956    2.4983797333325866
# 99987                    None                 None      -2.536517471033044
#
#                     Debt
# index
# 59              7,37e+04
# 80               3308906
# 116                  one
# 128    44372.86947464095
# 157           €99,167.87
# ...                  ...
# 99876            missing
# 99917            unknown
# 99952              51951
# 99973            36,870#
# 99987                one
#
# [5160 rows x 10 columns]

# %% [markdown]
# We can see:
#
# - Rows containing numbers with text in the selected column.
# - Presence of alphabetical currencies like USD in numbers. E.g: ``(USD111,650.31)``
# - Presence of text like **'approx'** in numbers. E.g: ``(approx 1000)``
# - Presence of random text in numbers. E.g: ``(116c48)``

# %% [markdown]
# ##### 13. **has_multiple_commas** -> Numbers containing more than one comma

# %%
diagnosis['Salary']['has_multiple_commas']
# Out:
#                          Age      Salary           Expenses  \
# index
# 39       85.39119238523617    111,500,69            4300,39
# 214                        ?   35,140,26               2114
# 400                     five  176,944,27               None
# 442                       68  130,609,42           2284.15
# 506                     2209   72,412,62               2094
# ...                      ...         ...                ...
# 99625                  error   86,182,36             6,276#
# 99719                      0   84,339,53               None
# 99762                     67   22,168,94               None
# 99959                   None  102,971,63               296g
# 99971       94.2010668796936  121,090,87  6988.532513292033
#
#                     Height_cm               Weight_kg      Temperature_C  \
# index
# 39                     156.51    113.42847314651515                   8#
# 214                      None                    five  17.16526560551941
# 400      188.13323368825326        106.20531559751271               None
# 442                    204.64    127.66946046843346    7.622790296831802
# 506                  1.91e+02                    None                  ?
# ...                       ...                     ...                ...
# 99625                     194                  141.39                 45
# 99719                  198.34                      41               0,27
# 99762                  165.87                    None  44.24835973546875
# 99959                  179.95                    None               -1cm
# 99971                     one                      83               1255
#
#          Purchase_Amount             Score                  Rating  \
# index
# 39               280.50              63.23      3.5016909340924096
# 214             4152.84               None                     N/A
# 400               266.02              None       2.393853010731272
# 442                  one          5.10e+01                      3$
# 506              3280,45                 ?    3.8286487554519573
# ...                  ...               ...                     ...
# 99625             3,549#             46.86                     2cm
# 99719           1.03e+03  95.9725406926238                    1.30
# 99762           3,75e+03                13      1.5038496235709644
# 99959               None               N/A                4.59e+00
# 99971  2687.705482794283                4K                    2,51
#
#                      Debt
# index
# 39       86593.9885648507
# 214    1513.1369537517814
# 400                  None
# 442              6,39e+04
# 506                  7646
# ...                   ...
# 99625             14,728#
# 99719             missing
# 99762            8.45e+04
# 99959                   ?
# 99971           83,905.55
#
# [1046 rows x 10 columns]

# %% [markdown]
# We can see:
#
# - Rows containing multiple commas in numbers, in the selected column.
# - Presence of multiple commas, both - **thousand separators** and **decimal replacements** in a single value.. E.g: ``(176,944,27)``
# - Presence of multiple commas is valid if commas are used as thousand separators, not as decimal replacements in a single value.
#
# Usually, valid numbers with multilple commas are represented like this -> ``1,000,555.23``

# %% [markdown]
# ##### 14. **has_multiple_decimals** -> Numbers containing more than one decimal point.

# %%
diagnosis['Salary']['has_multiple_decimals']
# Out:
#                      Age      Salary                Expenses  \
# index
# 36                 93.01   35.343.06                 5,657kg
# 192                57.88  149.918.17                  7,825$
# 827                    ?  190.714.89                 6164.42
# 992             2.41e+01  163.835.46                5312.81
# 1169                4346  138.876.05    1854.6488482739023
# ...                  ...         ...                     ...
# 99009                  3   47.337.78                  307785
# 99275              error   28.239.73                     one
# 99560               None  115.709.27       2356.778369868802
# 99609  73.40236686371765  153.300.12                     N/A
# 99857           3,09e+01  159.013.57               USD966.71
#
#                     Height_cm          Weight_kg           Temperature_C  \
# index
# 36                          ?  69.16754859811246                     -11
# 192                      186#           40.09 kg    -8.571189561945724
# 827        150.21944136513636                138                    0.90
# 992                  1.65e+02           65.51 kg                      26
# 1169                      160              140kg                      39
# ...                       ...                ...                     ...
# 99009                     156              10626                      N1
# 99275    191.34703054588581                 75cm                    None
# 99560                  152.19              69.74                   14.02
# 99609                    None              three                   48,58
# 99857                1,71e+02                 69    0.7008553394550141
#
#               Purchase_Amount              Score              Rating  \
# index
# 36       3962.8835885375865                 2978                   1
# 192                         ?                  4             missing
# 827                    201,70  68.34592378360729                  2$
# 992         875.5619021664696               81kg                   1
# 1169                  1,453kg              83.39                None
# ...                       ...                ...                 ...
# 99009                   error               None               three
# 99275     1815.657564529909               65.58   3.0114260441236333
# 99560    409.14476690756743                 five             unknown
# 99609                    2911               27cm                 4cm
# 99857       4825.719028717887               None                   2
#
#                     Debt
# index
# 36                 23757
# 192    91852.42585796413
# 827    75871.06754567151
# 992              45,966$
# 1169                   ?
# ...                  ...
# 99009           4.55e+04
# 99275          47563.28
# 99560         €96,256.54
# 99609               None
# 99857           1,32e+04
#
# [516 rows x 10 columns]

# %% [markdown]
# We can see:
#
# - Rows containing multiple decimal points in the selected column.
# - Presence of 2 decimal points in a single number. E.g: ``(138.876.05)``
#
# Multiple decimal points are usually invalid until and unless the domain specifically requires it.
#
# ##### **Valid Multiple Decimal Examples**:
#
# **IP Address:** ``192.168.0.1``

# %% [markdown]
# Great!
#
# We now know how we can diagnose dirty numerical data using ``diagnose_numbers()`` method of ``DirtyDataDiagnosis`` class.
#
# We have explored:
#
# 1. **Valid Numbers**
# 2. **Dirty Numbers**
# 3. **Only Text**
# 4. **Only Symbols**
# 5. **Only Missing**
# 6. **Only Scientific Notations**
# 7. **Numbers containing spaces**
# 8. **Numbers containing text**
# 9. **Numbers containing single decimals**
# 10. **Numbers containing multiple decimals**
# 11. **Numbers containing single commas**
# 12. **Numbers containing multiple commas**
# 13. **Numbers containing units**
# 14. **Numbers containing currency symbols**
