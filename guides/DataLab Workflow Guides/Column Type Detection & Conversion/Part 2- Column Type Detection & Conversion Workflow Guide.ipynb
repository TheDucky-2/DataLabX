# %% [markdown]
# # **Part 2: Column Type Detection & Conversion Workflow Guide (Continued)...**
# --------------------------------------------------------

# %%
import datalab as dl

# %%
from datalab import load_tabular

df = load_tabular('Ultimate_dirty_dataset.csv')

# %%
from datalab import Diagnosis

Diagnosis(df).detect_column_types()
# Out:
# {'Numerical': ['user_id',
#   'phone',
#   'billing_amount',
#   'session_length_sec',
#   'feedback_score'],
#  'Datetime': [],
#  'Categorical': ['age',
#   'gender',
#   'account_created_at',
#   'last_seen_at',
#   'account_closed_at',
#   'country_code',
#   'city',
#   'email',
#   'plan_tier',
#   'currency',
#   'event_time',
#   'event_type',
#   'notes']}
